# %%
import numpy as np
from matplotlib import pyplot as plt
from os import path
plt.rcParams['figure.dpi'] = 300
plt.rcParams.update({"axes.grid" : True, "grid.color": "whitesmoke"})
plt.rcParams['axes.axisbelow'] = True

# %%
thresholds=np.array([43.1,49.9,52,49,42.1,58.6,58,49,62.4,48.5,63.6,59,42.6,58.3,47.1,62.2,43.3,62.4,46.2,50.7,70.3,
59.3,46.9,62.5,43.3,47.5,63.4,52,56.2,61.3,47,54.5,66.6,62.3,47.1,46.6,55,53.3,44.6,48.3,60.2,70.2,
43.3,44.1,63,46.2,55.2,50.3,43.6,47.2,42.4,60,47.3,45.6,58.5,59.3,57,42.8,67.1,47.3,46.9,46.9,60.4,
58.6,47,43,57.7,66.1,43,47.3,59,38.7,41.5])

# %%
plt.hist(thresholds,bins=10)
ax=plt.gca()
ax.set_xlabel('Threshold (mV)')
ax.set_ylabel('Entries')
ax.set_title(" Threshold (mV) distribution ")
# Out:
# Text(0.5, 1.0, ' Threshold (mV) distribution ')

# %%
mean=np.mean(thresholds)
std=np.std(thresholds)
print("Thresholds mean %.2f $\\pm$ %.2f" %(mean,std))
# Out:
# Thresholds mean 52.64 $\pm$ 8.09

# %%
peakheigts=np.array([109.1,88.9,91.4,116.9,85.6,100.2,99.3,113.9,107.2,97.5,112.5,106.3,89.8,102.9,102.2,111.4,103.8,107.9,111.2,
114.2,112,107.2,98,106.6,91.8,90.6,112.4,96.7,97.4,106.4,119.6,108.3,118.4,107.7,109.2,119.4,96.6,95.5,98.7,105,
107,120.4,107.8,97.7,110.4,113.1,108.5,93.2,78.4,107.8,77.1,105.9,108.4,98,102.6,102.4,105.8,113.2,123.7,121.4,
86.2,98.1,109.1,103.5,118.4,88.5,102.4,113.4,107.4,106.4,101.9,66.6,97])

# %%
plt.hist(peakheigts,bins=10)
ax=plt.gca()
ax.set_xlabel('Spectrum peak (mV)')
ax.set_ylabel('Entries')
ax.set_title(" Distribution of the spectrum peak ")
# Out:
# Text(0.5, 1.0, ' Distribution of the spectrum peak ')

# %%
mean=np.mean(peakheigts)
std=np.std(peakheigts)
print("Thresholds mean %.2f $\\pm$ %.2f" %(mean,std))
# Out:
# Thresholds mean 103.72 $\pm$ 10.69

# %%
low_peakheigts=peakheigts[peakheigts<90]

# %%
len(low_peakheigts)
# Out:
# 8
