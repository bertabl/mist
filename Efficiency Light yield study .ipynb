# %%
import ROOT
from ROOT import gStyle
gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.28/00

# %%
#open data for scetion 1 and fit the spectrum mean 
myFile_1= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec1_triple_eff_test_spectra_waves/RAW/HcompassR_sec1_triple_eff_test_spectra_waves_20240528_151520.root")
dir_1 = myFile_1.GetDirectory("Energy");
hist_1 = dir_1.Get("_R_EnergyCH2@DT5751_1616;1")
hist_1.Rebin(35)
hist_1.Fit("gaus", "", "",1000,1600)
gfit_1= hist_1.GetFunction("gaus")
m1=gfit_1.GetParameter(1)
m1_err= gfit_1.GetParError(1)
# Out:
#  FCN=19.6236 FROM MIGRAD    STATUS=CONVERGED      90 CALLS          91 TOTAL
#                      EDM=2.52118e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.03706e+02   6.60822e+00   1.00576e-02  -1.12649e-04
#    2  Mean         1.31086e+03   9.05384e+00   2.01058e-02  -4.01865e-05
#    3  Sigma        3.12772e+02   1.85749e+01   4.44406e-05  -6.91476e-03
# Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

# %%
#open data for scetion 2 and fit the spectrum mean 
myFile_2= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec2_triple_eff_test_spectra_waves/RAW/HcompassR_sec2_triple_eff_test_spectra_waves_20240528_213801.root")
dir_2 = myFile_2.GetDirectory("Energy");
hist_2 = dir_2.Get("_R_EnergyCH2@DT5751_1616;1")
hist_2.Rebin(35)
hist_2.Fit("gaus", "", "",1000,1600)
gfit_2= hist_2.GetFunction("gaus")
m2=gfit_2.GetParameter(1)
m2_err= gfit_2.GetParError(1)
# Out:
#  FCN=18.2224 FROM MIGRAD    STATUS=CONVERGED      91 CALLS          92 TOTAL
#                      EDM=3.39556e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.85218e+02   7.40796e+00   1.11441e-02   3.66550e-05
#    2  Mean         1.31254e+03   6.51412e+00   1.38828e-02  -6.93574e-06
#    3  Sigma        2.75870e+02   1.14175e+01   2.84853e-05   1.94586e-02

# %%
#open data for scetion 2 and fit the spectrum mean 
myFile_3= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec3_triple_eff_test_spectra_waves/RAW/HcompassR_sec3_triple_eff_test_spectra_waves_20240530_161549.root")
dir_3 = myFile_3.GetDirectory("Energy");
hist_3 = dir_3.Get("_R_EnergyCH2@DT5751_1616;1")
hist_3.Rebin(35)
hist_3.Fit("gaus", "", "",1000,1600)
gfit_3= hist_3.GetFunction("gaus")
m3=gfit_3.GetParameter(1)
m3_err= gfit_3.GetParError(1)
# Out:
#  FCN=38.5485 FROM MIGRAD    STATUS=CONVERGED      90 CALLS          91 TOTAL
#                      EDM=1.46567e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.89730e+02   7.47205e+00   1.63149e-02   7.49508e-06
#    2  Mean         1.29099e+03   5.72783e+00   1.74102e-02  -2.21364e-06
#    3  Sigma        2.55539e+02   9.17958e+00   3.43768e-05   4.46758e-03

# %%
#open data for scetion 2 and fit the spectrum mean 
myFile_4= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec4_triple_eff_test_spectra_waves/RAW/HcompassR_sec4_triple_eff_test_spectra_waves_20240530_212636.root")
dir_4 = myFile_4.GetDirectory("Energy");
hist_4 = dir_4.Get("_R_EnergyCH2@DT5751_1616;1")
hist_4.Rebin(35)
hist_4.Fit("gaus", "", "",1000,1600)
gfit_4= hist_4.GetFunction("gaus")
m4=gfit_4.GetParameter(1)
m4_err= gfit_4.GetParError(1)
# Out:
#  FCN=22.8389 FROM MIGRAD    STATUS=CONVERGED      91 CALLS          92 TOTAL
#                      EDM=4.51029e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.88891e+02   7.32862e+00   1.25065e-02  -2.67211e-06
#    2  Mean         1.25404e+03   7.83216e+00   1.57754e-02  -4.32377e-06
#    3  Sigma        2.83320e+02   1.24183e+01   3.08550e-05  -1.18625e-03

# %%
#open data for scetion 5 and fit the spectrum mean 
myFile_5= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec5_triple_eff_test_spectra_waves/RAW/HcompassR_sec5_triple_eff_test_spectra_waves_20240601_215016.root")
dir_5 = myFile_5.GetDirectory("Energy");
hist_5 = dir_5.Get("_R_EnergyCH2@DT5751_1616;1")
hist_5.Rebin(35)
hist_5.Fit("gaus", "", "",1000,1600)
gfit_5= hist_5.GetFunction("gaus")
m5=gfit_5.GetParameter(1)
m5_err= gfit_5.GetParError(1)
# Out:
#  FCN=23.1327 FROM MIGRAD    STATUS=CONVERGED      93 CALLS          94 TOTAL
#                      EDM=1.70179e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.58320e+02   4.76113e+00   8.00262e-03   1.46588e-05
#    2  Mean         1.31077e+03   1.02187e+01   2.43400e-02  -2.39447e-06
#    3  Sigma        2.76399e+02   1.79776e+01   5.00086e-05   2.43905e-03

# %%
#open data for scetion 6 and fit the spectrum mean 
myFile_6= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec6_triple_eff_test_spectra_waves/RAW/HcompassR_sec6_triple_eff_test_spectra_waves_20240603_151605.root")
dir_6 = myFile_6.GetDirectory("Energy");
hist_6 = dir_6.Get("_R_EnergyCH2@DT5751_1616;1")
hist_6.Rebin(35)
hist_6.Fit("gaus", "", "",1000,1600)
gfit_6= hist_6.GetFunction("gaus")
m6=gfit_6.GetParameter(1)
m6_err= gfit_6.GetParError(1)
# Out:
#  FCN=15.2916 FROM MIGRAD    STATUS=CONVERGED      78 CALLS          79 TOTAL
#                      EDM=5.58347e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   9.6 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.49147e+02   6.97393e+00  -2.94031e-03  -4.53127e-05
#    2  Mean         1.32115e+03   8.22510e+00   6.91702e-02   5.18906e-06
#    3  Sigma        3.07038e+02   1.60124e+01  -7.55878e-05   5.12965e-03

# %%
#open data for scetion 6 and fit the spectrum mean 
myFile_7= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec7_triple_eff_test_spectra_waves/RAW/HcompassR_sec7_triple_eff_test_spectra_waves_20240603_203118.root")
dir_7 = myFile_7.GetDirectory("Energy");
hist_7 = dir_7.Get("_R_EnergyCH2@DT5751_1616;1")
hist_7.Rebin(35)
hist_7.Fit("gaus", "", "",1000,1600)
gfit_7= hist_7.GetFunction("gaus")
m7=gfit_7.GetParameter(1)
m7_err= gfit_7.GetParError(1)
# Out:
#  FCN=34.3828 FROM MIGRAD    STATUS=CONVERGED      91 CALLS          92 TOTAL
#                      EDM=4.82273e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.39191e+02   6.96425e+00   1.42483e-02  -7.74882e-06
#    2  Mean         1.29796e+03   6.66592e+00   1.93114e-02  -7.03237e-06
#    3  Sigma        2.69743e+02   1.14225e+01   3.92602e-05   2.01817e-03

# %%
#open data for scetion 6 and fit the spectrum mean 
myFile_8= ROOT.TFile.Open("/Users/bertabeltran/mist/data/efficiency_test/sec8_triple_eff_test_spectra_waves/RAW/HcompassR_sec8_triple_eff_test_spectra_waves_20240604_161917.root")
dir_8 = myFile_8.GetDirectory("Energy");
hist_8 = dir_8.Get("_R_EnergyCH2@DT5751_1616;1")
hist_8.Rebin(35)
hist_8.Fit("gaus", "", "",800,1600)
gfit_8= hist_8.GetFunction("gaus")
m8=gfit_8.GetParameter(1)
m8_err= gfit_8.GetParError(1)

c=ROOT.TCanvas("c0"," ",1400,1000)
hist_8.Draw()
c.Draw()
# Out:
#  FCN=17.5861 FROM MIGRAD    STATUS=CONVERGED      76 CALLS          77 TOTAL
#                      EDM=7.61349e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.10539e+02   3.46437e+00   5.34460e-03  -2.65976e-04
#    2  Mean         1.24301e+03   9.72525e+00   1.93992e-02  -1.53619e-05
#    3  Sigma        2.85608e+02   1.23297e+01   2.59441e-05   2.48847e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0

# %%
c0 = ROOT.TCanvas("c0"," ",1400,1000)


hist_4.SetLineColor(4)
hist_4.SetFillColor(0)
hist_4.SetNormFactor(1)
hist_4.GetYaxis().SetTitleOffset(1.2) #1.2
hist_4.Draw("same")


hist_7.SetLineColor(7)
hist_7.SetFillColor(0)
hist_7.SetNormFactor(1)
hist_7.Draw("same")


hist_8.SetLineColor(8)
hist_8.SetFillColor(0)
hist_8.SetNormFactor(1)
hist_8.Draw("same")


hist_1.SetLineColor(1)
hist_1.SetFillColor(0)
hist_1.SetNormFactor(1)

#hist_1.GetYaxis().SetRangeUser(0, 0.05) #1.2

hist_1.Draw("same")

hist_2.SetLineColor(2)
hist_2.SetFillColor(0)
hist_2.SetNormFactor(1)
hist_2.Draw("same")

hist_3.SetLineColor(3)
hist_3.SetFillColor(0)
hist_3.SetNormFactor(1)
hist_3.Draw("same")

hist_5.SetLineColor(5)
hist_5.SetFillColor(0)
hist_5.SetNormFactor(1)
hist_5.Draw("same")

hist_6.SetLineColor(6)
hist_6.SetFillColor(0)
hist_6.SetNormFactor(1)
hist_6.Draw("same")





leg = ROOT.TLegend(.5,.5,.9,.9)
leg.AddEntry(hist_1,"Section 1, mean ={:.1f} #pm {:.1f}".format(m1, m1_err),"L")
leg.AddEntry(hist_2,"Section 2, mean ={:.1f} #pm {:.1f}".format(m2, m2_err),"L")
leg.AddEntry(hist_3,"Section 3, mean ={:.1f} #pm {:.1f}".format(m3, m3_err),"L")
leg.AddEntry(hist_4,"Section 4, mean ={:.1f} #pm {:.1f}".format(m4, m4_err),"L")
leg.AddEntry(hist_5,"Section 5, mean ={:.1f} #pm {:.1f}".format(m5, m5_err),"L")
leg.AddEntry(hist_6,"Section 6, mean ={:.1f} #pm {:.1f}".format(m6, m6_err),"L")
leg.AddEntry(hist_7,"Section 7, mean ={:.1f} #pm {:.1f}".format(m7, m7_err),"L")
leg.AddEntry(hist_8,"Section 8, mean ={:.1f} #pm {:.1f}".format(m8, m8_err),"L")

leg.Draw()



c0.Draw()
c0.SaveAs("/Users/bertabeltran/mist/data/efficiency_test/light_yield_comp.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0
# Info in <TCanvas::Print>: png file /Users/bertabeltran/mist/data/efficiency_test/light_yield_comp.png has been created
