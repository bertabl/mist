# %%
import uproot
file = uproot.open("/Users/bertabeltran/muon_data/data/DataR_CH0@DT5751_1615_April_24_100lsb.root")

# %%
file.classnames()
# Out:
# {'Data_R;1': 'TTree'}

# %%
tree=file['Data_R']
branches = tree.arrays()
tree.arrays()
# Out:
# <Array [{Channel: 0, Timestamp: ..., ...}, ...] type='9240 * {Channel: uint...'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(branches['Energy'],bins=1000, range=(0, 17500))
plt.xlabel('ADC channel')
plt.ylabel('Counts')
plt.yscale('log')
plt.show()

# %%
plt.hist(branches['Timestamp'],bins=1000)
plt.show()
